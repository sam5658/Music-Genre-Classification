# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !unzip /content/gdrive/MyDrive/archive.zip

# %%
import librosa
import librosa.display

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import matplotlib.pyplot as plt , numpy as np , os , json

# %%
song , sr = librosa.load('/content/Data/genres_original/jazz/jazz.00054.wav')
librosa.display.waveplot(song)

# %%
def plot_spectrogram(Y, sr, hop_length, y_axis="linear"):
    plt.figure(figsize=(10, 5))
    librosa.display.specshow(Y, sr=sr, hop_length=1024, x_axis="time", y_axis=y_axis)
    plt.colorbar(format="%+2.f")
Y_log = librosa.power_to_db(np.abs(librosa.stft(song, hop_length=1024))**2)
plot_spectrogram(Y_log, sr, 1024)

# %%
mfcc_song = librosa.feature.mfcc(song, n_mfcc=13, sr=sr)
print(type(mfcc_song) )
plt.figure(figsize=(15, 8))
librosa.display.specshow(mfcc_song, x_axis="time", sr=sr)
plt.colorbar(format="%+2.f")
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
SOURCE_PATH = '/content/Data/genres_original/'


JSON_PATH = 'data.json'
#sampling rate
sr = 22050

TOTAL_SAMPLES = 29 * sr 

NUM_SLICES = 10
SAMPLES_PER_SLICE = int(TOTAL_SAMPLES / NUM_SLICES)

# %%
def preprocess_data(source_path):
    
    mydict = {
        "labels" : [] ,
         "mfcc" : []  
          }
    
    music = ['reggae', 'jazz', 'country', 'hiphop', 'rock', 'metal', 'classical', 'disco', 'blues', 'pop']
    
    path = 'Data/genres_original/'
    i = 0 


    for n in music : 
       new_path = path + n
       song = os.listdir(new_path)
       for p in song:
            if p != ".ipynb_checkpoints" :
                final_path = new_path + "/" + p
            #here we first walk through all the files and generate a 13 band mfcc for each sample and append it in the dict 
                melody , sr = librosa.load(final_path , duration=29)
            #creating 10 samples for each file
                for s in range(NUM_SLICES): 
                   start_sample = SAMPLES_PER_SLICE * s
                   end_sample = start_sample + SAMPLES_PER_SLICE
                   print("start: " , start_sample , ", end: " , end_sample )
                   mfcc = librosa.feature.mfcc(melody[start_sample : end_sample], sr=sr, n_mfcc=13)
                   mfcc = mfcc.T
                   print(mfcc.shape)
                   mydict["labels"].append(i)
                   mydict["mfcc"].append(mfcc.tolist()) 
       print(i)
       i+= 1 
    with open("data.json", 'w') as f:
        json.dump(mydict, f)
    f.close()

# %%
def load_data(json_path):

    with open(json_path, 'r') as f:
        data = json.load(f)
    f.close()

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    print(X.shape)

    return X, y

# %%
preprocess_data("Data/genres_original")

# %%
with open("data.json", 'r') as f:
        data = json.load(f)
f.close()
x = np.array(data["mfcc"])
y = np.array(data["labels"])

# %%
x = x.reshape( x.shape[0] , x.shape[1] , x.shape[2] , 1)

# %%
train_data_in ,test_data_in , train_data_targets  ,  test_data_targets = train_test_split(x , y , test_size = 0.1 )
inputs_train, inputs_test, targets_train, targets_test = train_test_split(train_data_in , train_data_targets, test_size=0.1)

# %%
def design_model(input_shape):

    # Let's design the model architecture.
    model = tf.keras.models.Sequential([
        
        tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        
        
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.Dropout(0.3),
        
        tf.keras.layers.Conv2D(128, (2,2), activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        
        
        tf.keras.layers.Dropout(0.3),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'), 
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    return model

# %%
shape_ = (125 , 13 , 1)
model1 = design_model(shape_)
model1.summary()
model1.compile(
       optimizer = 'adam' ,
       loss = 'sparse_categorical_crossentropy' ,
       metrics = 'accuracy'
)

model_history = model1.fit(
                        inputs_train, targets_train,
                        validation_data=(inputs_test, targets_test),
                        epochs=40,
                        batch_size=64
                        )
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_87 (Conv2D)          (None, 123, 11, 32)       320
#
#  max_pooling2d_87 (MaxPoolin  (None, 62, 6, 32)        0
#  g2D)
#
#  conv2d_88 (Conv2D)          (None, 60, 4, 64)         18496
#
#  max_pooling2d_88 (MaxPoolin  (None, 30, 2, 64)        0
#  g2D)
#
#  dropout_58 (Dropout)        (None, 30, 2, 64)         0
#
#  conv2d_89 (Conv2D)          (None, 29, 1, 128)        32896
#
#  max_pooling2d_89 (MaxPoolin  (None, 15, 1, 128)       0
#  g2D)
#
#  dropout_59 (Dropout)        (None, 15, 1, 128)        0
#
#  flatten_29 (Flatten)        (None, 1920)              0
#
#  dense_62 (Dense)            (None, 128)               245888
#
#  dense_63 (Dense)            (None, 64)                8256
#
#  dense_64 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 306,506
# Trainable params: 306,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 127/127 [==============================] - 3s 9ms/step - loss: 2.3667 - accuracy: 0.2917 - val_loss: 1.6748 - val_accuracy: 0.4444
# Epoch 2/40
# 127/127 [==============================] - 1s 6ms/step - loss: 1.5395 - accuracy: 0.4404 - val_loss: 1.4483 - val_accuracy: 0.4789
# Epoch 3/40
# 127/127 [==============================] - 1s 6ms/step - loss: 1.3397 - accuracy: 0.4999 - val_loss: 1.2431 - val_accuracy: 0.5722
# Epoch 4/40
# 127/127 [==============================] - 1s 6ms/step - loss: 1.2077 - accuracy: 0.5627 - val_loss: 1.1850 - val_accuracy: 0.5811
# Epoch 5/40
# 127/127 [==============================] - 1s 6ms/step - loss: 1.1142 - accuracy: 0.5906 - val_loss: 1.1220 - val_accuracy: 0.6122
# Epoch 6/40
# 127/127 [==============================] - 1s 6ms/step - loss: 1.0684 - accuracy: 0.6132 - val_loss: 1.0392 - val_accuracy: 0.6622
# Epoch 7/40
# 127/127 [==============================] - 1s 8ms/step - loss: 0.9740 - accuracy: 0.6484 - val_loss: 0.9752 - val_accuracy: 0.6689
# Epoch 8/40
# 127/127 [==============================] - 1s 9ms/step - loss: 0.9125 - accuracy: 0.6736 - val_loss: 1.0227 - val_accuracy: 0.6289
# Epoch 9/40
# 127/127 [==============================] - 1s 9ms/step - loss: 0.8819 - accuracy: 0.6878 - val_loss: 0.8877 - val_accuracy: 0.6944
# Epoch 10/40
# 127/127 [==============================] - 1s 7ms/step - loss: 0.8306 - accuracy: 0.7005 - val_loss: 0.8541 - val_accuracy: 0.7100
# Epoch 11/40
# 127/127 [==============================] - 1s 6ms/step - loss: 0
40
# 127/127 [==============================] - 1s 6ms/step - loss: 0.3014 - accuracy: 0.8928 - val_loss: 0.6547 - val_accuracy: 0.7956
# Epoch 37/40
# 127/127 [==============================] - 1s 6ms/step - loss: 0.2891 - accuracy: 0.8975 - val_loss: 0.6812 - val_accuracy: 0.7822
# Epoch 38/40
# 127/127 [==============================] - 1s 7ms/step - loss: 0.2797 - accuracy: 0.8968 - val_loss: 0.6735 - val_accuracy: 0.7867
# Epoch 39/40
# 127/127 [==============================] - 1s 8ms/step - loss: 0.2683 - accuracy: 0.9040 - val_loss: 0.7375 - val_accuracy: 0.7733
# Epoch 40/40
# 127/127 [==============================] - 1s 9ms/step - loss: 0.2748 - accuracy: 0.9022 - val_loss: 0.6253 - val_accuracy: 0.7867

# %%
model_history.history
def plot_performance(hist):
    
    acc = hist.history['accuracy']
    val_acc = hist.history['val_accuracy']
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()  

    plt.show()

plot_performance(model_history)

# %%
def get_mfcc(path):
  song , sr = librosa.load(path , duration = 29)
  librosa.display.waveplot(song)
  mfcc_song = librosa.feature.mfcc(song[ 383670 :  447615], n_mfcc=13, sr=sr)
  mfcc_song = mfcc_song.T 
  mfcc_song = np.array(mfcc_song)
  
  return mfcc_song

# %%
X = get_mfcc("/content/Data/genres_original/jazz/jazz.00055.wav")
X = X.reshape( 1 , 125  , 13 ,1 )
print(X.shape)
# Out:
# (1, 125, 13, 1)

# %%
predict = model1.predict(test_data_in)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
acc = 0 
for i in range(len(predict)):
  print(i + 1 , "predicted: " , np.argmax(predict[i]) , "actual: " , test_data_targets[i] )
  if np.argmax(predict[i]) == test_data_targets[i]:
    acc += 1 
print("accuracy : " , acc/1000* 100 , "%" )
# Out:
# 1 predicted:  0 actual:  0
# 2 predicted:  9 actual:  9
# 3 predicted:  5 actual:  5
# 4 predicted:  3 actual:  4
# 5 predicted:  3 actual:  3
# 6 predicted:  5 actual:  5
# 7 predicted:  5 actual:  5
# 8 predicted:  1 actual:  6
# 9 predicted:  9 actual:  0
# 10 predicted:  3 actual:  3
# 11 predicted:  8 actual:  8
# 12 predicted:  4 actual:  3
# 13 predicted:  0 actual:  0
# 14 predicted:  8 actual:  8
# 15 predicted:  9 actual:  9
# 16 predicted:  0 actual:  3
# 17 predicted:  7 actual:  4
# 18 predicted:  3 actual:  0
# 19 predicted:  9 actual:  7
# 20 predicted:  9 actual:  3
# 21 predicted:  4 actual:  4
# 22 predicted:  8 actual:  3
# 23 predicted:  4 actual:  4
# 24 predicted:  6 actual:  6
# 25 predicted:  8 actual:  2
# 26 predicted:  0 actual:  7
# 27 predicted:  1 actual:  1
# 28 predicted:  5 actual:  5
# 29 predicted:  3 actual:  3
# 30 predicted:  7 actual:  0
# 31 predicted:  9 actual:  9
# 32 predicted:  0 actual:  0
# 33 predicted:  7 actual:  8
# 34 predicted:  8 actual:  8
# 35 predicted:  0 actual:  0
# 36 predicted:  1 actual:  1
# 37 predicted:  4 actual:  4
# 38 predicted:  8 actual:  8
# 39 predicted:  3 actual:  3
# 40 predicted:  8 actual:  8
# 41 predicted:  1 actual:  1
# 42 predicted:  7 actual:  7
# 43 predicted:  2 actual:  2
# 44 predicted:  7 actual:  7
# 45 predicted:  4 actual:  5
# 46 predicted:  9 actual:  9
# 47 predicted:  1 actual:  1
# 48 predicted:  9 actual:  9
# 49 predicted:  8 actual:  8
# 50 predicted:  4 actual:  4
# 51 predicted:  8 actual:  8
# 52 predicted:  5 actual:  5
# 53 predicted:  9 actual:  9
# 54 predicted:  2 actual:  2
# 55 predicted:  1 actual:  1
# 56 predicted:  0 actual:  0
# 57 predicted:  8 actual:  8
# 58 predicted:  2 actual:  9
# 59 predicted:  0 actual:  0
# 60 predicted:  5 actual:  4
# 61 predicted:  4 actual:  4
# 62 predicted:  2 actual:  8
# 63 predicted:  1 actual:  1
# 64 predicted:  5 actual:  5
# 65 predicted:  6 actual:  6
# 66 predicted:  0 actual:  0
# 67 predicted:  3 actual:  4
# 68 predicted:  8 actual:  8
# 69 predicted:  0 actual:  7
# 70 predicted:  7 actual:  9
# 71 predicted:  6 actual:  6
# 72 predicted:  1 actual:  1
# 73 predicted:  9 actual:  9
# 74 predicted:  3 actual:  3
# 75 predicted:  5 actual:  5
# 76 predicted:  7 actual:  7
# 77 predicted:  8 actual:  8
# 78 predicted:  3 actual:  0
# 79 predicted:  2 actual:  2
# 80 predicted:  9 actual:  9
# 81 predicted:  4 actual:  4
# 82 predicted:  0 actual:  0
# 83 predicted:  7 actual:  7
# 84 predicted:  2 actual:  2
# 85 predicted:  8 actual:  8
# 86 predicted:  8 actual:  8
# 87 predicted:  4 actual:  4
# 88 predicted:  2 actual:  2
# 89 predicted:  7 actual:  7
# 90 predicted:  9 actual:  9
# 91 predicted:  1 actual:  1
# 92 predicted:  8 actual:  8
# 93 predicted:  5 actual:  5
# 94 predicted:  3 actual:  3
# 95 predicted:  3 actual:  3
# 96 predicted:  2 actual:  2
# 97 predicted:  1 actual:  0
# 98 predicted:  8 actual:  1
# 99 predicted:  5 actual:  5
# 100 predicted:  6 actual:  6
# 101 predicted:  8 actual:  8
# 102 predicted:  9 actual:  9
# 103 predicted:  3 actual:  7
# 104 predicted:  6 actual:  6
# 105 predicted:  5 actual:  5
# 106 predicted:  2 actual:  2
# 107 predicted:  9 actual:  2
# 108 predicted:  5 actual:  5
# 109 predicted:  5 actual:  5
# 110 predicted:  0 actual:  0
# 111 predicted:  3 actual:  3
# 112 predicted:  9 actual:  9
# 113 predicted:  0 actual:  0
# 114 predicted:  5 actual:  5
# 115 predicted:  0 actual:  0
# 116 predicted:  5 actual:  5
# 117 predicted:  3 actual:  9
# 118 predicted:  4 actual:  4
# 119 predicted:  6 actual:  6
# 120 predicted:  3 actual:  0
# 121 predicted:  2 actual:  2
# 122 predicted:  0 actual:  0
# 123 predicted:  0 actual:  0
# 124 predicted:  0 actual:  0
# 388 predicted:  9 actual:  9
# 389 predicted:  4 actual:  4
# 390 predicted:  7 actual:  7
# 391 predicted:  8 actual:  4
# 392 predicted:  7 actual:  7
# 393 predicted:  4 actual:  7
# 394 predicted:  3 actual:  4
# 395 predicted:  6 actual:  6
# 396 predicted:  9 actual:  9
# 397 predicted:  7 actual:  7
# 398 predicted:  0 actual:  0
# 399 predicted:  2 actual:  8
# 400 predicted:  1 actual:  2
# 401 predicted:  3 actual:  3
# 402 predicted:  7 actual:  7
# 403 predicted:  3 actual:  8
# 404 predicted:  9 actual:  9
# 405 predicted:  4 actual:  4
# 406 predicted:  1 actual:  4
# 407 predicted:  7 actual:  7
# 408 predicted:  8 actual:  8
# 409 predicted:  8 actual:  8
# 410 predicted:  3 actual:  4
# 411 predicted:  3 actual:  3
# 412 predicted:  1 actual:  1
# 413 predicted:  7 actual:  0
# 414 predicted:  0 actual:  0
# 415 predicted:  5 actual:  5
# 416 predicted:  4 actual:  4
# 417 predicted:  6 actual:  6
# 418 predicted:  1 actual:  1
# 419 predicted:  1 actual:  1
# 420 predicted:  1 actual:  1
# 421 predicted:  6 actual:  6
# 422 predicted:  3 actual:  3
# 423 predicted:  8 actual:  2
# 424 predicted:  4 actual:  7
# 425 predicted:  5 actual:  5
# 426 predicted:  0 actual:  0
# 427 predicted:  8 actual:  8
# 428 predicted:  2 actual:  2
# 429 predicted:  9 actual:  9
# 430 predicted:  5 actual:  5
# 431 predicted:  7 actual:  7
# 432 predicted:  5 actual:  5
# 433 predicted:  5 actual:  5
# 434 predicted:  3 actual:  3
# 435 predicted:  5 actual:  5
# 436 predicted:  8 actual:  8
# 437 predicted:  0 actual:  0
# 438 predicted:  9 actual:  9
# 439 predicted:  8 actual:  8
# 440 predicted:  3 actual:  0
# 441 predicted:  9 actual:  9
# 442 predicted:  7 actual:  7
# 443 predicted:  1 actual:  1
# 444 predicted:  9 actual:  3
# 445 predicted:  6 actual:  6
# 446 predicted:  9 actual:  9
# 447 predicted:  2 actual:  2
# 448 predicted:  9 actual:  3
# 449 predicted:  0 actual:  9
# 450 predicted:  5 actual:  5
# 451 predicted:  7 actual:  7
# 452 predicted:  7 actual:  7
# 453 predicted:  8 actual:  8
# 454 predicted:  5 actual:  5
# 455 predicted:  1 actual:  1
# 456 predicted:  6 actual:  6
# 457 predicted:  3 actual:  7
# 458 predicted:  6 actual:  6
# 459 predicted:  9 actual:  9
# 460 predicted:  2 actual:  2
# 461 predicted:  8 actual:  8
# 462 predicted:  7 actual:  7
# 463 predicted:  6 actual:  6
# 464 predicted:  7 actual:  7
# 465 predicted:  8 actual:  8
# 466 predicted:  9 actual:  9
# 467 predicted:  9 actual:  9
# 468 predicted:  4 actual:  4
# 469 predicted:  2 actual:  2
# 470 predicted:  2 actual:  4
# 471 predicted:  5 actual:  4
# 472 predicted:  1 actual:  1
# 473 predicted:  5 actual:  5
# 474 predicted:  9 actual:  7
# 475 predicted:  2 actual:  2
# 651 predicted:  9 actual:  9
# 652 predicted:  6 actual:  6
# 653 predicted:  3 actual:  3
# 654 predicted:  3 actual:  7
# 655 predicted:  7 actual:  4
# 656 predicted:  9 actual:  9
# 657 predicted:  1 actual:  1
# 658 predicted:  6 actual:  6
# 659 predicted:  5 actual:  5
# 660 predicted:  9 actual:  2
# 661 predicted:  9 actual:  9
# 662 predicted:  8 actual:  8
# 663 predicted:  3 actual:  9
# 664 predicted:  4 actual:  4
# 665 predicted:  8 actual:  2
# 666 predicted:  7 actual:  7
# 667 predicted:  5 actual:  5
# 668 predicted:  2 actual:  2
# 669 predicted:  2 actual:  2
# 670 predicted:  1 actual:  1
# 671 predicted:  5 actual:  5
# 672 predicted:  8 actual:  8
# 673 predicted:  2 actual:  2
# 674 predicted:  2 actual:  2
# 675 predicted:  0 actual:  2
# 676 predicted:  9 actual:  9
# 677 predicted:  8 actual:  8
# 678 predicted:  4 actual:  4
# 679 predicted:  7 actual:  7
# 680 predicted:  1 actual:  1
# 681 predicted:  3 actual:  7
# 682 predicted:  8 actual:  8
# 683 predicted:  6 actual:  6
# 684 predicted:  3 actual:  0
# 685 predicted:  8 actual:  8
# 686 predicted:  5 actual:  5
# 687 predicted:  2 actual:  1
# 688 predicted:  5 actual:  5
# 689 predicted:  9 actual:  9
# 690 predicted:  6 actual:  1
# 691 predicted:  3 actual:  0
# 692 predicted:  8 actual:  8
# 693 predicted:  2 actual:  2
# 694 predicted:  3 actual:  3
# 695 predicted:  8 actual:  8
# 696 predicted:  7 actual:  7
# 697 predicted:  0 actual:  0
# 698 predicted:  3 actual:  0
# 699 predicted:  2 actual:  2
# 700 predicted:  9 actual:  2
# 701 predicted:  8 actual:  8
# 702 predicted:  9 actual:  9
# 703 predicted:  5 actual:  4
# 704 predicted:  6 actual:  6
# 705 predicted:  6 actual:  6
# 706 predicted:  1 actual:  1
# 707 predicted:  1 actual:  1
# 708 predicted:  3 actual:  7
# 709 predicted:  6 actual:  6
# 710 predicted:  2 actual:  4
# 711 predicted:  1 actual:  1
# 712 predicted:  8 actual:  3
# 713 predicted:  3 actual:  3
# 714 predicted:  3 actual:  0
# 715 predicted:  1 actual:  1
# 716 predicted:  8 actual:  8
# 717 predicted:  3 actual:  7
# 718 predicted:  6 actual:  6
# 719 predicted:  3 actual:  3
# 720 predicted:  3 actual:  0
# 721 predicted:  9 actual:  9
# 722 predicted:  1 actual:  1
# 723 predicted:  6 actual:  6
# 724 predicted:  4 actual:  0
# 725 predicted:  6 actual:  6
# 726 predicted:  5 actual:  5
# 727 predicted:  8 actual:  8
# 728 predicted:  7 actual:  2
# 729 predicted:  2 actual:  2
# 730 predicted:  3 actual:  0
# 731 predicted:  7 actual:  7
# 732 predicted:  5 actual:  5
# 733 predicted:  5 actual:  5
# 734 predicted:  1 actual:  1
# 735 predicted:  4 actual:  4
# 736 predicted:  7 actual:  6
# 737 predicted:  8 actual:  8
# 738 predicted:  9 actual:  4
# 739 predicted:  9 actual:  3
# 740 predicted:  0 actual:  0
# 741 predicted:  4 actual:  5
# 742 predicted:  3 actual:  3
# 743 predicted:  0 actual:  0
# 744 predicted:  5 actual:  5
# 745 predicted:  7 actual:  7
# 746 predicted:  1 actual:  2
# 747 predicted:  1 actual:  1
# 748 predicted:  9 actual:  9
# 749 predicted:  0 actual:  0
# 750 predicted:  5 actual:  5
# 751 predicted:  1 actual:  1
# 752 predicted:  3 actual:  2
# 753 predicted:  3 actual:  3
# 754 predicted:  9 actual:  9
# 755 predicted:  6 actual:  6
# 756 predicted:  4 actual:  4
# 757 predicted:  6 actual:  6
# 758 predicted:  1 actual:  4
# 759 predicted:  1 actual:  1
# 760 predicted:  6 actual:  6
# 761 predicted:  3 actual:  0
# 762 predicted:  0 actual:  0
# 763 predicted:  2 actual:  2
# 764 predicted:  3 actual:  4
# 765 predicted:  6 actual:  6
# 766 predicted:  0 actual:  0
# 767 predicted:  6 actual:  6
# 768 predicted:  3 actual:  3
# 769 predicted:  5 actual:  5
# 770 predicted:  3 actual:  9
# 771 predicted:  3 actual:  3
# 772 predicted:  2 actual:  2
# 773 predicted:  0 actual:  3
# 774 predicted:  6 actual:  6
# 775 predicted:  9 actual:  9
# 776 predicted:  8 actual:  8
# 777 predicted:  5 actual:  5
# 778 predicted:  3 actual:  3
# 779 predicted:  0 actual:  0
# 780 predicted:  6 actual:  6
# 781 predicted:  2 actual:  2
# 782 predicted:  5 actual:  5
# 783 predicted:  8 actual:  8
# 784 predicted:  0 actual:  0
# 785 predicted:  0 actual:  0
# 786 predicted:  9 actual:  9
# 787 predicted:  2 actual:  2
# 788 predicted:  1 actual:  1
# 789 predicted:  9 actual:  9
# 790 predicted:  1 actual:  1
# 791 predicted:  4 actual:  4
# 792 predicted:  7 actual:  7
# 793 predicted:  5 actual:  5
# 794 predicted:  1 actual:  4
# 795 predicted:  5 actual:  5
# 796 predicted:  8 actual:  8
# 797 predicted:  2 actual:  2
# 798 predicted:  5 actual:  5
# 799 predicted:  8 actual:  2
# 800 predicted:  3 actual:  7
# 801 predicted:  5 actual:  5
# 802 predicted:  0 actual:  0
# 803 predicted:  5 actual:  5
# 804 predicted:  1 actual:  2
# 805 predicted:  3 actual:  4
# 806 predicted:  4 actual:  9
# 807 predicted:  8 actual:  8
# 808 predicted:  9 actual:  9
# 809 predicted:  4 actual:  4
# 810 predicted:  5 actual:  5
# 811 predicted:  2 actual:  2
# 812 predicted:  5 actual:  5
# 813 predicted:  6 actual:  6
# 814 predicted:  1 actual:  1
# 815 predicted:  3 actual:  3
# 816 predicted:  1 actual:  1
# 817 predicted:  2 actual:  2
# 818 predicted:  5 actual:  5
# 819 predicted:  1 actual:  6
# 820 predicted:  4 actual:  4
# 821 predicted:  0 actual:  0
# 822 predicted:  9 actual:  9
# 823 predicted:  8 actual:  8
# 824 predicted:  1 actual:  1
# 825 predicted:  7 actual:  7
# 826 predicted:  9 actual:  9
# 827 predicted:  7 actual:  7
# 828 predicted:  7 actual:  7
# 829 predicted:  1 actual:  1
# 830 predicted:  7 actual:  7
# 831 predicted:  5 actual:  5
# 832 predicted:  2 actual:  2
# 833 predicted:  4 actual:  4
# 834 predicted:  7 actual:  7
# 835 predicted:  9 actual:  9
# 836 predicted:  4 actual:  4
# 837 predicted:  0 actual:  0
# 838 predicted:  9 actual:  9
# 839 predicted:  1 actual:  1
# 840 predicted:  9 actual:  9
# 841 predicted:  9 actual:  9
# 842 predicted:  2 actual:  2
# 843 predicted:  1 actual:  6
# 844 predicted:  1 actual:  7
# 845 predicted:  5 actual:  5
# 846 predicted:  9 actual:  9
# 847 predicted:  4 actual:  4
# 848 predicted:  6 actual:  6
# 849 predicted:  8 actual:  8
# 850 predicted:  9 actual:  2
# 851 predicted:  5 actual:  5
# 852 predicted:  9 actual:  9
# 853 predicted:  9 actual:  9
# 854 predicted:  8 actual:  8
# 855 predicted:  1 actual:  1
# 856 predicted:  9 actual:  2
# 857 predicted:  6 actual:  6
# 858 predicted:  1 actual:  1
# 859 predicted:  3 actual:  0
# 860 predicted:  7 actual:  7
# 861 predicted:  2 actual:  2
# 862 predicted:  9 actual:  9
# 863 predicted:  1 actual:  1
# 864 predicted:  8 actual:  8
# 865 predicted:  2 actual:  2
# 866 predicted:  0 actual:  0
# 867 predicted:  7 actual:  7
# 868 predicted:  4 actual:  5
# 869 predicted:  6 actual:  6
# 870 predicted:  4 actual:  4
# 871 predicted:  0 actual:  0
# 872 predicted:  2 actual:  2
# 873 predicted:  2 actual:  2
# 874 predicted:  3 actual:  3
# 875 predicted:  9 actual:  9
# 876 predicted:  6 actual:  6
# 877 predicted:  1 actual:  4
# 878 predicted:  2 actual:  2
# 879 predicted:  7 actual:  2
# 880 predicted:  6 actual:  6
# 881 predicted:  9 actual:  9
# 882 predicted:  2 actual:  2
# 883 predicted:  4 actual:  4
# 884 predicted:  8 actual:  8
# 885 predicted:  5 actual:  4
# 886 predicted:  5 actual:  5
# 887 predicted:  9 actual:  9
# 888 predicted:  5 actual:  5
# 889 predicted:  5 actual:  5
# 890 predicted:  1 actual:  1
# 891 predicted:  0 actual:  0
# 892 predicted:  5 actual:  5
# 893 predicted:  4 actual:  2
# 894 predicted:  7 actual:  7
# 895 predicted:  3 actual:  3
# 896 predicted:  5 actual:  5
# 897 predicted:  5 actual:  5
# 898 predicted:  0 actual:  0
# 899 predicted:  6 actual:  6
# 900 predicted:  6 actual:  6
# 901 predicted:  5 actual:  5
# 902 predicted:  9 actual:  9
# 903 predicted:  8 actual:  8
# 904 predicted:  6 actual:  6
# 905 predicted:  2 actual:  2
# 906 predicted:  0 actual:  0
# 907 predicted:  8 actual:  8
# 908 predicted:  5 actual:  5
# 909 predicted:  7 actual:  7
# 910 predicted:  0 actual:  0
# 911 predicted:  5 actual:  5
# 912 predicted:  3 actual:  3
# 913 predicted:  9 actual:  9
# 914 predicted:  5 actual:  5
# 915 predicted:  0 actual:  7
# 916 predicted:  9 actual:  9
# 917 predicted:  8 actual:  8
# 918 predicted:  0 actual:  0
# 919 predicted:  5 actual:  5
# 920 predicted:  8 actual:  8
# 921 predicted:  8 actual:  8
# 922 predicted:  7 actual:  7
# 923 predicted:  4 actual:  4
# 924 predicted:  7 actual:  7
# 925 predicted:  6 actual:  6
# 926 predicted:  1 actual:  1
# 927 predicted:  8 actual:  8
# 928 predicted:  6 actual:  6
# 929 predicted:  5 actual:  3
# 930 predicted:  7 actual:  7
# 931 predicted:  7 actual:  7
# 932 predicted:  0 actual:  0
# 933 predicted:  5 actual:  4
# 934 predicted:  2 actual:  2
# 935 predicted:  8 actual:  5
# 936 predicted:  0 actual:  0
# 937 predicted:  2 actual:  2
# 938 predicted:  2 actual:  2
# 939 predicted:  1 actual:  1
# 940 predicted:  9 actual:  9
# 941 predicted:  0 actual:  0
# 942 predicted:  3 actual:  3
# 943 predicted:  0 actual:  0
# 944 predicted:  6 actual:  6
# 945 predicted:  8 actual:  8
# 946 predicted:  6 actual:  6
# 947 predicted:  1 actual:  1
# 948 predicted:  5 actual:  5
# 949 predicted:  1 actual:  1
# 950 predicted:  6 actual:  6
# 951 predicted:  0 actual:  0
# 952 predicted:  2 actual:  2
# 953 predicted:  1 actual:  1
# 954 predicted:  3 actual:  3
# 955 predicted:  3 actual:  3
# 956 predicted:  4 actual:  2
# 957 predicted:  2 actual:  2
# 958 predicted:  4 actual:  4
# 959 predicted:  6 actual:  6
# 960 predicted:  4 actual:  5
# 961 predicted:  3 actual:  9
# 962 predicted:  3 actual:  3
# 963 predicted:  2 actual:  4
# 964 predicted:  5 actual:  5
# 965 predicted:  2 actual:  2
# 966 predicted:  6 actual:  6
# 967 predicted:  6 actual:  6
# 968 predicted:  3 actual:  3
# 969 predicted:  5 actual:  5
# 970 predicted:  9 actual:  9
# 971 predicted:  8 actual:  3
# 972 predicted:  2 actual:  2
# 973 predicted:  9 actual:  9
# 974 predicted:  2 actual:  2
# 975 predicted:  6 actual:  6
# 976 predicted:  6 actual:  6
# 977 predicted:  0 actual:  0
# 978 predicted:  5 actual:  5
# 979 predicted:  7 actual:  7
# 980 predicted:  6 actual:  1
# 981 predicted:  2 actual:  2
# 982 predicted:  1 actual:  1
# 983 predicted:  7 actual:  0
# 984 predicted:  9 actual:  9
# 985 predicted:  4 actual:  5
# 986 predicted:  2 actual:  2
# 987 predicted:  1 actual:  1
# 988 predicted:  5 actual:  4
# 989 predicted:  4 actual:  9
# 990 predicted:  8 actual:  5
# 991 predicted:  0 actual:  0
# 992 predicted:  2 actual:  2
# 993 predicted:  0 actual:  0
# 994 predicted:  3 actual:  9
# 995 predicted:  6 actual:  6
# 996 predicted:  1 actual:  1
# 997 predicted:  7 actual:  7
# 998 predicted:  0 actual:  0
# 999 predicted:  1 actual:  6
# 1000 predicted:  3 actual:  3
# accuracy :  79.0 %
